# %%
from pyspark.sql import Row

# Create initial DataFrame with sample data
data = [Row(id=1, name='Alice', age=30), Row(id=2, name='Bob', age=25), Row(id=3, name='Charlie', age=35)]
df = spark.createDataFrame(data)

# Overwrite and create a managed Delta table with the DataFrame in the training.delta_demo schema
df.write.format('delta').mode('overwrite').saveAsTable('training.delta_demo.people_delta_demo')

# Read the Delta table to verify creation and display its contents
delta_df = spark.read.table("training.delta_demo.people_delta_demo")
display(delta_df)

# %%
# %sql
select * from training.delta_demo.people_delta_demo

# %%
df.write.format('delta').mode('append').save("/Volumes/training/delta_demo/training/source_table")

# %%
df2 = spark.read.format('delta').load("/Volumes/training/delta_demo/training/source_table")
display(df2)

# %%
# %sql
CREATE OR REPLACE TABLE training.delta_demo.target_shallow SHALLOW CLONE training.delta_demo.people_delta_demo ;

# %%
# %sql
describe history training.delta_demo.target_shallow;

# %%
# %sql
select * from training.delta_demo.target_shallow

# %%
# %sql
CREATE OR REPLACE TABLE training.delta_demo.target_deep CLONE training.delta_demo.people_delta_demo ;
    
describe history training.delta_demo.target_deep;
