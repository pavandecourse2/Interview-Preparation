# %%
df=spark.read.csv("/Volumes/myfilescat/myfiles/myfiles/sales.csv")
display(df)

# %%
df=spark.read.format("csv").option("Header","true").option("inferSchema",True).load("/Volumes/myfilescat/myfiles/myfiles/sales.csv")
display(df)

# %%
Schema_hdr = " id int,customer_name String,product String,quanity Int,price double,remarks string"
df =spark.read.format("csv").schema(Schema_hdr).load("/Volumes/myfilescat/myfiles/myfiles/sales_no_header.csv")
display(df)

# %%
df= spark.read.format("csv")\
    .option("Header",True)\
        .option("InferSchema",True)\
            .option("delimiter","|")\
                .load("/Volumes/myfilescat/myfiles/myfiles/sales_pipe.csv")
display(df)

# %%
df= spark.read.format("csv")\
    .option("Header",True)\
        .option("InferSchema",True)\
            .option("delimiter","|")\
                .option("quote","'")\
                .load("/Volumes/myfilescat/myfiles/myfiles/sales_pipe_single_quote.csv")
display(df)

# %%
df= spark.read.format("csv")\
    .option("Header",True)\
        .option("InferSchema",True)\
            .option("delimiter","|")\
                .option("quote","'")\
                    .option("escape","#")\
                .load("/Volumes/myfilescat/myfiles/myfiles/sales_pipe_single_quote_escape.csv")
display(df)

# %%
df= spark.read.format("csv")\
    .option("Header",True)\
        .option("InferSchema",True)\
            .option("delimiter","|")\
                .option("quote","'")\
                    .option("escape","#")\
                       .option("multiline",True)\
                .load("/Volumes/myfilescat/myfiles/myfiles/sales_pipe_single_quote_escape_multiline.csv")
display(df)
