# %%
df= spark.read.format("json")\
    .option("Header",True)\
        .option("InferSchema",True)\
                .load("/Volumes/myfilescat/myfiles/myfiles/sales_single_line.json")
display(df)

# %%
df.write.format("parquet").save("/Volumes/myfilescat/myfiles/myfiles/outparquet.parquet")

# %%
df =spark.read.format("parquet").load("/Volumes/myfilescat/myfiles/myfiles/outparquet.parquet/")
display(df)
