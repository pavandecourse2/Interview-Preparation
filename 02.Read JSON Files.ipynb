# %%
df= spark.read.format("json")\
    .option("Header",True)\
        .option("InferSchema",True)\
                .load("/Volumes/myfilescat/myfiles/myfiles/sales_single_line.json")
display(df)

# %%
df= spark.read.format("json")\
    .option("Header",True)\
        .option("InferSchema",True)\
            .option("multiLine",True)\
                .load("/Volumes/myfilescat/myfiles/myfiles/sales_multi_line.json")
display(df)

# %%
df.write.format("csv").save("/Volumes/myfilescat/myfiles/myfiles/json_out.csv")
