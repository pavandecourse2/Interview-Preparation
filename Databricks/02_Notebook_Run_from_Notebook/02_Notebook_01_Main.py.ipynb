# %%
# Databricks notebook source
# MAGIC %md
# MAGIC # Notebook Overview
# MAGIC This notebook demonstrates how to orchestrate and modularize code in Databricks notebooks using `%run` and `dbutils.notebook.run`. It includes examples of passing parameters, handling outputs, and managing exceptions effectively.

# %% [markdown]
# # MAGIC %md
# # MAGIC ## %run wihtout parameters

# %%
# %run "/Workspace/Users/pavandecourse2@gmail.com/Databricks/02_Notebook_Run_from_Notebook/02_Notebook_02_Utils_Without_Params.py"

# %%
print("Test Variable=",test_variable)
print("Area of Circle=",area_of_circle(5))

# %%
# MAGIC %md
# MAGIC ## %run wih parameters

# %%
# %run "/Workspace/Users/pavandecourse2@gmail.com/Databricks/02_Notebook_Run_from_Notebook/02_Notebook_03_Utils_With_Params.py"  $name="PavanKumar" $radius="15"

# %%
# MAGIC %md
# MAGIC # DButils

# %%
# MAGIC %md
# MAGIC ## DButils without Parameters

# %%
dbutils.notebook.run("/Workspace/Users/pavandecourse2@gmail.com/Databricks/02_Notebook_Run_from_Notebook/02_Notebook_02_Utils_Without_Params.py",60)

# %%
# MAGIC %md
# MAGIC ## DButils with Parameters

# %%
dbutils.notebook.run("./02_Notebook_03_Utils_With_Params",60,{"name":"Narender","radius":"50"})

# %%
# MAGIC %md
# MAGIC ## DButils receive Output

# %%
circle_area=dbutils.notebook.run("/Workspace/Users/pavandecourse2@gmail.com/Databricks/02_Notebook_Run_from_Notebook/02_Notebook_04_Utils_With_Output.py",60,{"name":"PavanKumar","radius":"50"})
print("Circle Area:",circle_area)

# %%
# MAGIC %md
# MAGIC ## DButils Handle Exceptions

# %%
try:
    output = dbutils.notebook.run("/Workspace/Users/pavandecourse2@gmail.com/Databricks/02_Notebook_Run_from_Notebook/02_Notebook_05_Utils_With_Output_and_Exception.py",60,{"name":"Narender","radius":"50"})
    print(output)
except Exception as e:
    print("Child notebook failed:", e)
