# %%
# Databricks notebook source
test_variable="Narender"

# COMMAND ----------

def area_of_circle(r):
    return 3.14159 * r * r

# COMMAND ----------

print(f"Helper notebook executed Successfully")
